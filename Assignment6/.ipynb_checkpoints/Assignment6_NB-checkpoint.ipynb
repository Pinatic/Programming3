# %% [markdown]
# # Assignment 6
# ## Project 1
# The first project you can choose is a continuation of the InterPROscan dataset you worked on for Assignment 5. You now know the structure and type of data that is involved. What I would ike you to do is to develop scikit-learn machine learning models to predict the function of the proteins in the dataset. I'm not going to mandate any particular model, but you should use your knowledge from DS3 to determine good candidate methods and try a couple, and report on yourGiven the size of the data, you should train your machine models in parallel! Dask is an obvious candidate for this, but you can also use any of the other frameworks we discussed in the course.
#
# The "function" of the protein which is the "class" your model should predict is defined as the InterPRO number which covers:
#
# 1. more than 90% of the protein's sequence
# 2. Covers the largest length of the sequence
#
# The "features" that you use to predict that class are the other, smaller, InterPRO annotations. Take care to remove "noise" from the dataset, ie. lines from the TSV file which don't contain InterPRO numbers, proteins which don't have a large feature (according to the criteria above) etc. Be sure to note in your report how you processed the data and why you made the choices you did!
#
# Your script should, given one or more of these TSV files with InterPROscan annotations, produce models (Pickle them to save them!) which predict protein function, and a file of training-data on which you trained them.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data preperation

# %%
#path = "/data/dataprocessing/interproscan/all_bacilli.tsv"
path = "all_bacilli.tsv"
#path = "bacilli_sample_1000.tsv"
df = pd.read_csv(path, sep = "\t", names = ["Protein_acc", "Sequence_MD5", "Sequence_lenght", "Analysis", "Signature_acc", 
                                            "Signature_description", "Start_loc", "Stop_loc", "Score", "Status", 
                                           "Data", "Interpro_acc", "Interpro_descr", "GO_anno", "Pathway_anno"])

# %%
df
# Out:
#                           Protein_acc                      Sequence_MD5  \
# 0          gi|29898682|gb|AAP11954.1|  92d1264e347e149248231cb9b649388c
# 1          gi|29898682|gb|AAP11954.1|  92d1264e347e149248231cb9b649388c
# 2          gi|29898682|gb|AAP11954.1|  92d1264e347e149248231cb9b649388c
# 3          gi|29898682|gb|AAP11954.1|  92d1264e347e149248231cb9b649388c
# 4          gi|29898682|gb|AAP11954.1|  92d1264e347e149248231cb9b649388c
# ...                               ...                               ...
# 4200586  gi|530338482|emb|CDG26962.1|  902da1e8e06f749e0ad8bf4986be765f
# 4200587  gi|530338482|emb|CDG26962.1|  902da1e8e06f749e0ad8bf4986be765f
# 4200588  gi|530338482|emb|CDG26962.1|  902da1e8e06f749e0ad8bf4986be765f
# 4200589  gi|530338482|emb|CDG26962.1|  902da1e8e06f749e0ad8bf4986be765f
# 4200590  gi|530338482|emb|CDG26962.1|  902da1e8e06f749e0ad8bf4986be765f
#
#          Sequence_lenght         Analysis       Signature_acc  \
# 0                    547          TIGRFAM           TIGR03882
# 1                    547          TIGRFAM           TIGR03604
# 2                    547  ProSiteProfiles             PS51664
# 3                    547           Gene3D  G3DSA:3.30.160.660
# 4                    547           Gene3D   G3DSA:3.30.40.250
# ...                  ...              ...                 ...
# 4200586              276          PANTHER       PTHR33745:SF8
# 4200587              276             Pfam             PF01740
# 4200588              276             Pfam             PF13426
# 4200589              276      SUPERFAMILY            SSF52091
# 4200590              276          PANTHER           PTHR33745
#
#                                      Signature_description  Start_loc  \
# 0        cyclo_dehyd_2: bacteriocin biosynthesis cyclod...          2
# 1        TOMM_cyclo_SagD: thiazole/oxazole-forming pept...        161
# 2                                     YcaO domain profile.        159
# 3                                                        -        311
# 4                                                        -        191
# ...                                                    ...        ...
# 4200586                           BLUE-LIGHT PHOTORECEPTOR         16
# 4200587                                        STAS domain        166
# 4200588                                         PAS domain         42
# 4200589                                       SpoIIaa-like        163
# 4200590               RSBT ANTAGONIST PROTEIN RSBS-RELATED         16
#
#          Stop_loc      Score Status        Data Interpro_acc  \
# 0             131    1.6E-21      T  25-04-2022    IPR022291
# 1             547        0.0      T  25-04-2022    IPR027624
# 2             547  75.396477      T  25-04-2022    IPR003776
# 3             452    9.1E-46      T  25-04-2022            -
# 4             274    9.1E-46      T  25-04-2022            -
# ...           ...        ...    ...         ...          ...
# 4200586       275   5.0E-127      T  25-04-2022            -
# 4200587       269     1.1E-6      T  25-04-2022    IPR002645
# 4200588       143    2.5E-20      T  25-04-2022    IPR000014
# 4200589       273   1.18E-12      T  25-04-2022    IPR036513
# 4200590       275   5.0E-127      T  25-04-2022            -
#
#                                             Interpro_descr GO_anno  \
# 0        Bacteriocin biosynthesis, cyclodehydratase domain       -
# 1        Thiazole/oxazole-forming peptide maturase, Sag...       -
# 2                                         YcaO-like domain       -
# 3                                                        -     NaN
# 4                                                        -     NaN
# ...                                                    ...     ...
# 4200586                                                  -     NaN
# 4200587                                        STAS domain       -
# 4200588                                         PAS domain       -
# 4200589                            STAS domain superfamily       -
# 4200590                                                  -     NaN
#
#                                               Pathway_anno
# 0                                                        -
# 1                                                        -
# 2                                                        -
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 4200586                                                NaN
# 4200587  MetaCyc: PWY-5921|Reactome: R-CEL-174362|React...
# 4200588  MetaCyc: PWY-4702|MetaCyc: PWY-5491|MetaCyc: P...
# 4200589  MetaCyc: PWY-5921|Reactome: R-CEL-174362|React...
# 4200590                                                NaN
#
# [4200591 rows x 15 columns]

# %%
df = df[df["Interpro_acc"] != "-"]

# %%
df
# Out:
#                           Protein_acc                      Sequence_MD5  \
# 0          gi|29898682|gb|AAP11954.1|  92d1264e347e149248231cb9b649388c
# 1          gi|29898682|gb|AAP11954.1|  92d1264e347e149248231cb9b649388c
# 2          gi|29898682|gb|AAP11954.1|  92d1264e347e149248231cb9b649388c
# 6          gi|29898682|gb|AAP11954.1|  92d1264e347e149248231cb9b649388c
# 8          gi|29898682|gb|AAP11954.1|  92d1264e347e149248231cb9b649388c
# ...                               ...                               ...
# 4200584  gi|530338482|emb|CDG26962.1|  902da1e8e06f749e0ad8bf4986be765f
# 4200585  gi|530338482|emb|CDG26962.1|  902da1e8e06f749e0ad8bf4986be765f
# 4200587  gi|530338482|emb|CDG26962.1|  902da1e8e06f749e0ad8bf4986be765f
# 4200588  gi|530338482|emb|CDG26962.1|  902da1e8e06f749e0ad8bf4986be765f
# 4200589  gi|530338482|emb|CDG26962.1|  902da1e8e06f749e0ad8bf4986be765f
#
#          Sequence_lenght         Analysis Signature_acc  \
# 0                    547          TIGRFAM     TIGR03882
# 1                    547          TIGRFAM     TIGR03604
# 2                    547  ProSiteProfiles       PS51664
# 6                    547          TIGRFAM     TIGR00702
# 8                    547             Pfam       PF02624
# ...                  ...              ...           ...
# 4200584              276            SMART       SM00086
# 4200585              276              CDD       cd00130
# 4200587              276             Pfam       PF01740
# 4200588              276             Pfam       PF13426
# 4200589              276      SUPERFAMILY      SSF52091
#
#                                      Signature_description  Start_loc  \
# 0        cyclo_dehyd_2: bacteriocin biosynthesis cyclod...          2
# 1        TOMM_cyclo_SagD: thiazole/oxazole-forming pept...        161
# 2                                     YcaO domain profile.        159
# 6                       TIGR00702: YcaO-type kinase domain        161
# 8               YcaO cyclodehydratase, ATP-ad Mg2+-binding        161
# ...                                                    ...        ...
# 4200584                                              pac_2        104
# 4200585                                                PAS         41
# 4200587                                        STAS domain        166
# 4200588                                         PAS domain         42
# 4200589                                       SpoIIaa-like        163
#
#          Stop_loc       Score Status        Data Interpro_acc  \
# 0             131     1.6E-21      T  25-04-2022    IPR022291
# 1             547         0.0      T  25-04-2022    IPR027624
# 2             547   75.396477      T  25-04-2022    IPR003776
# 6             501     2.2E-22      T  25-04-2022    IPR003776
# 8             501     8.6E-76      T  25-04-2022    IPR003776
# ...           ...         ...    ...         ...          ...
# 4200584       144      2.2E-6      T  25-04-2022    IPR001610
# 4200585       141  1.14681E-9      T  25-04-2022    IPR000014
# 4200587       269      1.1E-6      T  25-04-2022    IPR002645
# 4200588       143     2.5E-20      T  25-04-2022    IPR000014
# 4200589       273    1.18E-12      T  25-04-2022    IPR036513
#
#                                             Interpro_descr GO_anno  \
# 0        Bacteriocin biosynthesis, cyclodehydratase domain       -
# 1        Thiazole/oxazole-forming peptide maturase, Sag...       -
# 2                                         YcaO-like domain       -
# 6                                         YcaO-like domain       -
# 8                                         YcaO-like domain       -
# ...                                                    ...     ...
# 4200584                                          PAC motif       -
# 4200585                                         PAS domain       -
# 4200587                                        STAS domain       -
# 4200588                                         PAS domain       -
# 4200589                            STAS domain superfamily       -
#
#                                               Pathway_anno
# 0                                                        -
# 1                                                        -
# 2                                                        -
# 6                                                        -
# 8                                                        -
# ...                                                    ...
# 4200584  Reactome: R-DME-1234158|Reactome: R-DME-123417...
# 4200585  MetaCyc: PWY-4702|MetaCyc: PWY-5491|MetaCyc: P...
# 4200587  MetaCyc: PWY-5921|Reactome: R-CEL-174362|React...
# 4200588  MetaCyc: PWY-4702|MetaCyc: PWY-5491|MetaCyc: P...
# 4200589  MetaCyc: PWY-5921|Reactome: R-CEL-174362|React...
#
# [1921817 rows x 15 columns]
